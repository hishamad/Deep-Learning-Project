# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from cosine_annealing import CosineAnnealingScheduler
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage
import numpy as np

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset(noise_ratio=0, sym=True):
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    n_classes = 10

    if noise_ratio > 0:
        trainY_original = np.copy(trainY)
        if not sym:
            # Asymetric noise
            source_class = [9, 2, 3, 5, 4]
            target_class = [1, 0, 5, 3, 7]

            for s, t in zip(source_class, target_class):
                cls_idx = np.where(trainY_original == s)[0]
                n_noisy = int(noise_ratio * cls_idx.shape[0] / 100)
                noisy_sample_index = np.random.choice(cls_idx, n_noisy, replace=False)
                trainY[noisy_sample_index] = t
        else:
          # Symmetric noise

            n_samples = trainY.shape[0]
            n_noisy = int(noise_ratio * n_samples / 100)
            class_index = [np.where(trainY_original == i)[0] for i in range(n_classes)]
            class_noisy = int(n_noisy / n_classes)

            noisy_idx = []
            for d in range(n_classes):
                noisy_class_index = np.random.choice(class_index[d], class_noisy, replace=False)
                noisy_idx.extend(noisy_class_index)

            for i in noisy_idx:
                class_ind = trainY_original[i]
                other_class_list = list(range(n_classes))
                other_class_list.remove(class_ind)
                other_class = np.random.choice(other_class_list)
                trainY[i] = other_class

    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    train_mean = trainX.mean((0,1,2))
    train_std = trainX.std((0,1,2))

    trainX = (trainX - train_mean)# / train_std

    test_mean = testX.mean((0,1,2))
    test_std = testX.std((0,1,2))

    testX = (testX - test_mean)# / test_std

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):

	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)

	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)

	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Symmetric Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/contents/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %% [markdown]
# SL loss function

# %% [markdown]
# https://github.com/YisenWang/symmetric_cross_entropy_for_noisy_labels/blob/master/loss.py

# %%
def symmetric_cross_entropy(y_true, y_pred):
    alpha = 0.1
    beta = 1.0
    y_true_1 = y_true
    y_pred_1 = y_pred

    y_true_2 = y_true
    y_pred_2 = y_pred

    y_pred_1 = tf.clip_by_value(y_pred_1, 1e-7, 1.0)
    y_true_2 = tf.clip_by_value(y_true_2, 1e-4, 1.0)

    return alpha*tf.math.reduce_mean(-tf.math.reduce_sum(y_true_1 * tf.math.log(y_pred_1), axis = -1)) + beta*tf.math.reduce_mean(-tf.math.reduce_sum(y_pred_2 * tf.math.log(y_true_2), axis = -1))

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3), kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    total_steps = int(trainX.shape[0]/64) * 100
    decay_steps = total_steps*0.8
    initial_learning_rate = 0.01
    warmup_steps = 1000
    target_learning_rate = 0.1
    alpha_2 = 0.001

    lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate, decay_steps ,alpha = alpha_2
    )
    # Optimization method
    opt = SGD(learning_rate=lr_warmup_decayed_fn, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss=symmetric_cross_entropy, metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset(noise_ratio=40, sym=True)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 41s 42ms/step - loss: 8.2919 - accuracy: 0.2278 - val_loss: 6.3742 - val_accuracy: 0.4244
# Epoch 2/100
# 782/782 [==============================] - 33s 42ms/step - loss: 7.7735 - accuracy: 0.2878 - val_loss: 5.8621 - val_accuracy: 0.4741
# Epoch 3/100
# 782/782 [==============================] - 32s 41ms/step - loss: 7.4723 - accuracy: 0.3200 - val_loss: 5.6193 - val_accuracy: 0.5021
# Epoch 4/100
# 782/782 [==============================] - 32s 40ms/step - loss: 7.2407 - accuracy: 0.3448 - val_loss: 4.9961 - val_accuracy: 0.5624
# Epoch 5/100
# 782/782 [==============================] - 32s 41ms/step - loss: 7.0503 - accuracy: 0.3646 - val_loss: 4.6667 - val_accuracy: 0.5993
# Epoch 6/100
# 782/782 [==============================] - 31s 40ms/step - loss: 6.8810 - accuracy: 0.3806 - val_loss: 4.1990 - val_accuracy: 0.6488
# Epoch 7/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6.7637 - accuracy: 0.3921 - val_loss: 4.1008 - val_accuracy: 0.6546
# Epoch 8/100
# 782/782 [==============================] - 33s 42ms/step - loss: 6.6912 - accuracy: 0.4011 - val_loss: 3.8406 - val_accuracy: 0.6868
# Epoch 9/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6.5936 - accuracy: 0.4085 - val_loss: 3.7720 - val_accuracy: 0.6885
# Epoch 10/100
# 782/782 [==============================] - 33s 42ms/step - loss: 6.5250 - accuracy: 0.4162 - val_loss: 3.7993 - val_accuracy: 0.6854
# Epoch 11/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6.4868 - accuracy: 0.4189 - val_loss: 3.9910 - val_accuracy: 0.6647
# Epoch 12/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6.4102 - accuracy: 0.4288 - val_loss: 4.0091 - val_accuracy: 0.6598
# Epoch 13/100
# 782/782 [==============================] - 31s 40ms/step - loss: 6.4068 - accuracy: 0.4283 - val_loss: 3.2715 - val_accuracy: 0.7402
# Epoch 14/100
# 782/782 [==============================] - 32s 40ms/step - loss: 6.3511 - accuracy: 0.4352 - val_loss: 3.3089 - val_accuracy: 0.7375
# Epoch 15/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6.3172 - accuracy: 0.4398 - val_loss: 3.4611 - val_accuracy: 0.7206
# Epoch 16/100
# 782/782 [==============================] - 31s 40ms/step - loss: 6.3154 - accuracy: 0.4399 - val_loss: 3.4450 - val_accuracy: 0.7250
# Epoch 17/100
# 782/782 [==============================] - 32s 41ms/step - loss: 6
100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.7773 - accuracy: 0.4894 - val_loss: 2.5739 - val_accuracy: 0.8047
# Epoch 45/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.7461 - accuracy: 0.4921 - val_loss: 2.6239 - val_accuracy: 0.7964
# Epoch 46/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.7401 - accuracy: 0.4925 - val_loss: 2.6593 - val_accuracy: 0.7955
# Epoch 47/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.7043 - accuracy: 0.4956 - val_loss: 2.6496 - val_accuracy: 0.7943
# Epoch 48/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.6777 - accuracy: 0.4978 - val_loss: 2.6365 - val_accuracy: 0.7938
# Epoch 49/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.6649 - accuracy: 0.4987 - val_loss: 2.3863 - val_accuracy: 0.8199
# Epoch 50/100
# 782/782 [==============================] - 33s 43ms/step - loss: 5.6407 - accuracy: 0.4999 - val_loss: 2.5680 - val_accuracy: 0.8023
# Epoch 51/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.6246 - accuracy: 0.5012 - val_loss: 2.4443 - val_accuracy: 0.8154
# Epoch 52/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.5875 - accuracy: 0.5040 - val_loss: 2.3372 - val_accuracy: 0.8256
# Epoch 53/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.5611 - accuracy: 0.5071 - val_loss: 2.2779 - val_accuracy: 0.8296
# Epoch 54/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.5773 - accuracy: 0.5039 - val_loss: 2.3266 - val_accuracy: 0.8254
# Epoch 55/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.5297 - accuracy: 0.5081 - val_loss: 2.2642 - val_accuracy: 0.8306
# Epoch 56/100
# 782/782 [==============================] - 34s 44ms/step - loss: 5.5060 - accuracy: 0.5106 - val_loss: 2.4592 - val_accuracy: 0.8074
# Epoch 57/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.4908 - accuracy: 0.5111 - val_loss: 2.2647 - val_accuracy: 0.8287
# Epoch 58/100
# 782/782 [==============================] - 34s 43ms/step - loss: 5.4653 - accuracy: 0.5130 - val_loss: 2.1827 - val_accuracy: 0.8357
# Epoch 59/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.4461 - accuracy: 0.5150 - val_loss: 2.1888 - val_accuracy: 0.8338
# Epoch 60/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.4174 - accuracy: 0.5166 - val_loss: 2.1145 - val_accuracy: 0.8416
# Epoch 61/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.4062 - accuracy: 0.5178 - val_loss: 2.1289 - val_accuracy: 0.8383
# Epoch 62/100
# 782/782 [==============================] - 34s 43ms/step - loss: 5.3781 - accuracy: 0.5199 - val_loss: 2.0714 - val_accuracy: 0.8448
# Epoch 63/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.3689 - accuracy: 0.5202 - val_loss: 2.0551 - val_accuracy: 0.8481
# Epoch 64/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.3505 - accuracy: 0.5215 - val_loss: 2.0472 - val_accuracy: 0.8472
# Epoch 65/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.3264 - accuracy: 0.5236 - val_loss: 2.0269 - val_accuracy: 0.8496
# Epoch 66/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.3226 - accuracy: 0.5236 - val_loss: 2.0389 - val_accuracy: 0.8456
# Epoch 67/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2964 - accuracy: 0.5263 - val_loss: 1.9940 - val_accuracy: 0.8521
# Epoch 68/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2784 - accuracy: 0.5280 - val_loss: 1.9723 - val_accuracy: 0.8536
# Epoch 69/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.2713 - accuracy: 0.5272 - val_loss: 1.9962 - val_accuracy: 0.8495
# Epoch 70/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.2533 - accuracy: 0.5294 - val_loss: 1.9635 - val_accuracy: 0.8548
# Epoch 71/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2405 - accuracy: 0.5303 - val_loss: 1.9591 - val_accuracy: 0.8536
# Epoch 72/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.2321 - accuracy: 0.5318 - val_loss: 1.9463 - val_accuracy: 0.8566
# Epoch 73/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2293 - accuracy: 0.5310 - val_loss: 1.9178 - val_accuracy: 0.8599
# Epoch 74/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2227 - accuracy: 0.5321 - val_loss: 1.9100 - val_accuracy: 0.8603
# Epoch 75/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2081 - accuracy: 0.5331 - val_loss: 1.9133 - val_accuracy: 0.8593
# Epoch 76/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2076 - accuracy: 0.5335 - val_loss: 1.9189 - val_accuracy: 0.8599
# Epoch 77/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2210 - accuracy: 0.5318 - val_loss: 1.9016 - val_accuracy: 0.8611
# Epoch 78/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2069 - accuracy: 0.5333 - val_loss: 1.9071 - val_accuracy: 0.8602
# Epoch 79/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.1929 - accuracy: 0.5353 - val_loss: 1.9009 - val_accuracy: 0.8604
# Epoch 80/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.2063 - accuracy: 0.5333 - val_loss: 1.9047 - val_accuracy: 0.8600
# Epoch 81/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.1997 - accuracy: 0.5339 - val_loss: 1.9053 - val_accuracy: 0.8603
# Epoch 82/100
# 782/782 [==============================] - 34s 43ms/step - loss: 5.1946 - accuracy: 0.5348 - val_loss: 1.9046 - val_accuracy: 0.8604
# Epoch 83/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.1941 - accuracy: 0.5349 - val_loss: 1.9027 - val_accuracy: 0.8607
# Epoch 84/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.1894 - accuracy: 0.5344 - val_loss: 1.9050 - val_accuracy: 0.8596
# Epoch 85/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.1958 - accuracy: 0.5351 - val_loss: 1.9100 - val_accuracy: 0.8596
# Epoch 86/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.1989 - accuracy: 0.5348 - val_loss: 1.9016 - val_accuracy: 0.8600
# Epoch 87/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2033 - accuracy: 0.5341 - val_loss: 1.9055 - val_accuracy: 0.8600
# Epoch 88/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2007 - accuracy: 0.5335 - val_loss: 1.9012 - val_accuracy: 0.8604
# Epoch 89/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.1898 - accuracy: 0.5354 - val_loss: 1.9054 - val_accuracy: 0.8600
# Epoch 90/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.1976 - accuracy: 0.5342 - val_loss: 1.9031 - val_accuracy: 0.8601
# Epoch 91/100
# 782/782 [==============================] - 31s 40ms/step - loss: 5.1991 - accuracy: 0.5347 - val_loss: 1.9061 - val_accuracy: 0.8600
# Epoch 92/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.1923 - accuracy: 0.5344 - val_loss: 1.9016 - val_accuracy: 0.8603
# Epoch 93/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.2058 - accuracy: 0.5334 - val_loss: 1.9001 - val_accuracy: 0.8602
# Epoch 94/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.1862 - accuracy: 0.5362 - val_loss: 1.9011 - val_accuracy: 0.8601
# Epoch 95/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2064 - accuracy: 0.5332 - val_loss: 1.9079 - val_accuracy: 0.8595
# Epoch 96/100
# 782/782 [==============================] - 32s 40ms/step - loss: 5.1747 - accuracy: 0.5361 - val_loss: 1.9062 - val_accuracy: 0.8596
# Epoch 97/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.2014 - accuracy: 0.5342 - val_loss: 1.9036 - val_accuracy: 0.8594
# Epoch 98/100
# 782/782 [==============================] - 33s 42ms/step - loss: 5.1980 - accuracy: 0.5330 - val_loss: 1.9060 - val_accuracy: 0.8596
# Epoch 99/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.1964 - accuracy: 0.5340 - val_loss: 1.9008 - val_accuracy: 0.8600
# Epoch 100/100
# 782/782 [==============================] - 32s 41ms/step - loss: 5.1878 - accuracy: 0.5353 - val_loss: 1.9059 - val_accuracy: 0.8595

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 85.95%

# %%
save_model('SL_noisy_model_40_sym_dropout', model)
save_history('SL_noisy_model_40_sym_dropout_hist', results.history)
