# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):
	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)

	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)

	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/models/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/history/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/models/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/content/history/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    # Optimization method
    opt = SGD(learning_rate=0.01, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 40s 44ms/step - loss: 2.0241 - accuracy: 0.2355 - val_loss: 1.7212 - val_accuracy: 0.3679
# Epoch 2/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.6999 - accuracy: 0.3627 - val_loss: 1.4592 - val_accuracy: 0.4669
# Epoch 3/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.5329 - accuracy: 0.4390 - val_loss: 1.3265 - val_accuracy: 0.5182
# Epoch 4/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.4275 - accuracy: 0.4819 - val_loss: 1.2292 - val_accuracy: 0.5490
# Epoch 5/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3515 - accuracy: 0.5139 - val_loss: 1.1874 - val_accuracy: 0.5725
# Epoch 6/100
# 782/782 [==============================] - 31s 40ms/step - loss: 1.2729 - accuracy: 0.5453 - val_loss: 1.0206 - val_accuracy: 0.6286
# Epoch 7/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.2199 - accuracy: 0.5679 - val_loss: 1.1406 - val_accuracy: 0.5932
# Epoch 8/100
# 782/782 [==============================] - 31s 40ms/step - loss: 1.1797 - accuracy: 0.5835 - val_loss: 1.0014 - val_accuracy: 0.6376
# Epoch 9/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.1290 - accuracy: 0.6016 - val_loss: 0.9516 - val_accuracy: 0.6607
# Epoch 10/100
# 782/782 [==============================] - 31s 40ms/step - loss: 1.0854 - accuracy: 0.6193 - val_loss: 0.9294 - val_accuracy: 0.6723
# Epoch 11/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.0522 - accuracy: 0.6293 - val_loss: 0.9246 - val_accuracy: 0.6797
# Epoch 12/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.0208 - accuracy: 0.6424 - val_loss: 0.8220 - val_accuracy: 0.7124
# Epoch 13/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.9992 - accuracy: 0.6492 - val_loss: 0.8190 - val_accuracy: 0.7176
# Epoch 14/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.9803 - accuracy: 0.6599 - val_loss: 0.8547 - val_accuracy: 0.7049
# Epoch 15/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9581 - accuracy: 0.6711 - val_loss: 0.8039 - val_accuracy: 0.7291
# Epoch 16/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.9382 - accuracy: 0.6766 - val_loss: 0.8372 - val_accuracy: 0.7160
# Epoch 17/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9220 - accuracy: 0.6854 - val_loss: 0.7763 - val_accuracy: 0.7378
# Epoch 18/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8911 - accuracy: 0.6945 - val_loss: 0.7804 - val_accuracy: 0.7295
# Epoch 19/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8808 - accuracy: 0.6960 - val_loss: 0.7119 - val_accuracy: 0.7546
# Epoch 20/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8692 - accuracy: 0.7019 - val_loss: 0.7096 - val_accuracy: 0.7551
# Epoch 21/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8573 - accuracy: 0.7070 - val_loss: 0.8118 - val_accuracy: 0.7273
# Epoch 22/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.8336 - accuracy: 0.7135 - val_loss: 0.7134 - val_accuracy: 0.7645
# Epoch 23/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8351 - accuracy: 0.7154 - val_loss: 0.6771 - val_accuracy: 0.7688
# Epoch 24/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.8198 - accuracy: 0.7200 - val_loss: 0.6098 - val_accuracy: 0.7918
# Epoch 25/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8099 - accuracy: 0.7227 - val_loss: 0.7050 - val_accuracy: 0.7704
# Epoch 26/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.8002 - accuracy: 0.7302 - val_loss: 0.6588 - val_accuracy: 0.7808
# Epoch 27/100
# 782/782 [==============================] - 32s 42ms/step - loss: 0.7910 - accuracy: 0.7316 - val_loss: 0.6581 - val_accuracy: 0.7767
# Epoch 28/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.7780 - accuracy: 0.7340 - val_loss: 0.6246 - val_accuracy: 0.7879
# Epoch 29/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7821 - accuracy: 0.7344 - val_loss: 0.6236 - val_accuracy: 0.7871
# Epoch 30/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7641 - accuracy: 0.7396 - val_loss: 0.6477 - val_accuracy: 0.7819
# Epoch 31/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7654 - accuracy: 0.7391 - val_loss: 0.6749 - val_accuracy: 0.7725
# Epoch 32/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7550 - accuracy: 0.7454 - val_loss: 0.6059 - val_accuracy: 0.7923
# Epoch 33/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.7468 - accuracy: 0.7475 - val_loss: 0.6272 - val_accuracy: 0.7859
# Epoch 34/100
# 782/782 [==============================] - 42s 53ms/step - loss: 0.7329 - accuracy: 0.7519 - val_loss: 0.5783 - val_accuracy: 0.8110
# Epoch 35/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.7327 - accuracy: 0.7507 - val_loss: 0.6356 - val_accuracy: 0.7926
# Epoch 36/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7198 - accuracy: 0.7550 - val_loss: 0.5729 - val_accuracy: 0.8076
# Epoch 37/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.7265 - accuracy: 0.7549 - val_loss: 0.5956 - val_accuracy: 0.8001
# Epoch 38/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7235 - accuracy: 0.7588 - val_loss: 0.6336 - val_accuracy: 0.7885
# Epoch 39/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7172 - accuracy: 0.7583 - val_loss: 0.6004 - val_accuracy: 0.8024
# Epoch 40/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.7031 - accuracy: 0.7631 - val_loss: 0.7819 - val_accuracy: 0.7450
# Epoch 41/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7062 - accuracy: 0.7614 - val_loss: 0.6088 - val_accuracy: 0.7924
# Epoch 42/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.7096 - accuracy: 0.7627 - val_loss: 0.5953 - val_accuracy: 0.8040
# Epoch 43/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7026 - accuracy: 0.7651 - val_loss: 0.6008 - val_accuracy: 0.8062
# Epoch 44/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6920 - accuracy: 0.7662 - val_loss: 0.5583 - val_accuracy: 0.8126
# Epoch 45/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6907 - accuracy: 0.7676 - val_loss: 0.5604 - val_accuracy: 0.8114
# Epoch 46/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6872 - accuracy: 0.7705 - val_loss: 0.5856 - val_accuracy: 0.8077
# Epoch 47/100
# 782/782 [==============================] - 32s 42ms/step - loss: 0.6818 - accuracy: 0.7713 - val_loss: 0.6215 - val_accuracy: 0.7959
# Epoch 48/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6852 - accuracy: 0.7704 - val_loss: 0.6089 - val_accuracy: 0.7973
# Epoch 49/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6800 - accuracy: 0.7709 - val_loss: 0.6026 - val_accuracy: 0.8011
# Epoch 50/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6757 - accuracy: 0.7734 - val_loss: 0.6264 - val_accuracy: 0.7965
# Epoch 51/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6703 - accuracy: 0.7734 - val_loss: 0.5842 - val_accuracy: 0.8068
# Epoch 52/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6712 - accuracy: 0.7734 - val_loss: 0.6898 - val_accuracy: 0.7766
# Epoch 53/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.6691 - accuracy: 0.7757 - val_loss: 0.5585 - val_accuracy: 0.8141
# Epoch 54/100
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6688 - accuracy: 0.7762 - val_loss: 0.5633 - val_accuracy: 0.8095
# Epoch 55/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6687 - accuracy: 0.7744 - val_loss: 0.5498 - val_accuracy: 0.8190
# Epoch 56/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6639 - accuracy: 0.7812 - val_loss: 0.5466 - val_accuracy: 0.8161
# Epoch 57/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.6581 - accuracy: 0.7788 - val_loss: 0.5628 - val_accuracy: 0.8141
# Epoch 58/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.6570 - accuracy: 0.7804 - val_loss: 0.5479 - val_accuracy: 0.8171
# Epoch 59/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6560 - accuracy: 0.7797 - val_loss: 0.5437 - val_accuracy: 0.8200
# Epoch 60/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6555 - accuracy: 0.7813 - val_loss: 0.5487 - val_accuracy: 0.8167
# Epoch 61/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6486 - accuracy: 0.7816 - val_loss: 0.5768 - val_accuracy: 0.8116
# Epoch 62/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6509 - accuracy: 0.7817 - val_loss: 0.5411 - val_accuracy: 0.8211
# Epoch 63/100
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6553 - accuracy: 0.7800 - val_loss: 0.5195 - val_accuracy: 0.8235
# Epoch 64/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6441 - accuracy: 0.7809 - val_loss: 0.5414 - val_accuracy: 0.8184
# Epoch 65/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6451 - accuracy: 0.7828 - val_loss: 0.6113 - val_accuracy: 0.8010
# Epoch 66/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6390 - accuracy: 0.7858 - val_loss: 0.5370 - val_accuracy: 0.8293
# Epoch 67/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6398 - accuracy: 0.7841 - val_loss: 0.5540 - val_accuracy: 0.8167
# Epoch 68/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.6413 - accuracy: 0.7857 - val_loss: 0.6126 - val_accuracy: 0.8074
# Epoch 69/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6460 - accuracy: 0.7855 - val_loss: 0.5988 - val_accuracy: 0.8048
# Epoch 70/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6302 - accuracy: 0.7891 - val_loss: 0.5307 - val_accuracy: 0.8283
# Epoch 71/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6375 - accuracy: 0.7868 - val_loss: 0.5163 - val_accuracy: 0.8257
# Epoch 72/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.6308 - accuracy: 0.7899 - val_loss: 0.5541 - val_accuracy: 0.8164
# Epoch 73/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6338 - accuracy: 0.7898 - val_loss: 0.5244 - val_accuracy: 0.8275
# Epoch 74/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6272 - accuracy: 0.7888 - val_loss: 0.5694 - val_accuracy: 0.8125
# Epoch 75/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6292 - accuracy: 0.7900 - val_loss: 0.5384 - val_accuracy: 0.8240
# Epoch 76/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6326 - accuracy: 0.7872 - val_loss: 0.5288 - val_accuracy: 0.8274
# Epoch 77/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6202 - accuracy: 0.7921 - val_loss: 0.5976 - val_accuracy: 0.8066
# Epoch 78/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6260 - accuracy: 0.7914 - val_loss: 0.5403 - val_accuracy: 0.8193
# Epoch 79/100
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6280 - accuracy: 0.7877 - val_loss: 0.5973 - val_accuracy: 0.8129
# Epoch 80/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6272 - accuracy: 0.7927 - val_loss: 0.5155 - val_accuracy: 0.8260
# Epoch 81/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6242 - accuracy: 0.7937 - val_loss: 0.5388 - val_accuracy: 0.8256
# Epoch 82/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6219 - accuracy: 0.7926 - val_loss: 0.4952 - val_accuracy: 0.8314
# Epoch 83/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.6259 - accuracy: 0.7923 - val_loss: 0.5500 - val_accuracy: 0.8184
# Epoch 84/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6278 - accuracy: 0.7909 - val_loss: 0.5473 - val_accuracy: 0.8139
# Epoch 85/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.6212 - accuracy: 0.7939 - val_loss: 0.5216 - val_accuracy: 0.8306
# Epoch 86/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.6215 - accuracy: 0.7914 - val_loss: 0.5286 - val_accuracy: 0.8237
# Epoch 87/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6197 - accuracy: 0.7918 - val_loss: 0.5285 - val_accuracy: 0.8269
# Epoch 88/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6255 - accuracy: 0.7911 - val_loss: 0.4975 - val_accuracy: 0.8312
# Epoch 89/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6157 - accuracy: 0.7956 - val_loss: 0.5241 - val_accuracy: 0.8244
# Epoch 90/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6222 - accuracy: 0.7948 - val_loss: 0.5459 - val_accuracy: 0.8211
# Epoch 91/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6165 - accuracy: 0.7905 - val_loss: 0.5045 - val_accuracy: 0.8346
# Epoch 92/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6054 - accuracy: 0.7961 - val_loss: 0.5088 - val_accuracy: 0.8344
# Epoch 93/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6116 - accuracy: 0.7935 - val_loss: 0.5379 - val_accuracy: 0.8187
# Epoch 94/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6174 - accuracy: 0.7929 - val_loss: 0.5197 - val_accuracy: 0.8283
# Epoch 95/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6166 - accuracy: 0.7941 - val_loss: 0.5240 - val_accuracy: 0.8298
# Epoch 96/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.6207 - accuracy: 0.7934 - val_loss: 0.5518 - val_accuracy: 0.8203
# Epoch 97/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6236 - accuracy: 0.7925 - val_loss: 0.5317 - val_accuracy: 0.8317
# Epoch 98/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6215 - accuracy: 0.7952 - val_loss: 0.5338 - val_accuracy: 0.8244
# Epoch 99/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6144 - accuracy: 0.7991 - val_loss: 0.5037 - val_accuracy: 0.8402
# Epoch 100/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6104 - accuracy: 0.7954 - val_loss: 0.5813 - val_accuracy: 0.8110

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 81.10%

# %%
save_model('dropout_augment_model_experiment4', model)
save_history('dropout_augment_model_experiment4', results.history)

# %%
from google.colab import files
files.download('/content/models/dropout_augment_model_experiment4')
files.download('/content/history/dropout_augment_model_experiment4')

# %%
test = load_model('dropout_augment_model_experiment4')
history_test = load_history('dropout_augment_model_experiment4')

# %%
plot_results(history_test)
evaluate(test, testX, testY)
# Out:
# The model achieved a final accuracy of 81.10%
