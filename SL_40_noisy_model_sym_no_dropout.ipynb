# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from cosine_annealing import CosineAnnealingScheduler
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage
import numpy as np

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset(noise_ratio=0, sym=True):
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    n_classes = 10

    if noise_ratio > 0:
        trainY_original = np.copy(trainY)
        if not sym:
            # Asymetric noise
            source_class = [9, 2, 3, 5, 4]
            target_class = [1, 0, 5, 3, 7]

            for s, t in zip(source_class, target_class):
                cls_idx = np.where(trainY_original == s)[0]
                n_noisy = int(noise_ratio * cls_idx.shape[0] / 100)
                noisy_sample_index = np.random.choice(cls_idx, n_noisy, replace=False)
                trainY[noisy_sample_index] = t
        else:
          # Symmetric noise

            n_samples = trainY.shape[0]
            n_noisy = int(noise_ratio * n_samples / 100)
            class_index = [np.where(trainY_original == i)[0] for i in range(n_classes)]
            class_noisy = int(n_noisy / n_classes)

            noisy_idx = []
            for d in range(n_classes):
                noisy_class_index = np.random.choice(class_index[d], class_noisy, replace=False)
                noisy_idx.extend(noisy_class_index)

            for i in noisy_idx:
                class_ind = trainY_original[i]
                other_class_list = list(range(n_classes))
                other_class_list.remove(class_ind)
                other_class = np.random.choice(other_class_list)
                trainY[i] = other_class

    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    train_mean = trainX.mean((0,1,2))
    train_std = trainX.std((0,1,2))

    trainX = (trainX - train_mean)# / train_std

    test_mean = testX.mean((0,1,2))
    test_std = testX.std((0,1,2))

    testX = (testX - test_mean)# / test_std

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):

	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)
	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)


	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Symmetric Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/content/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %% [markdown]
# SL loss function

# %% [markdown]
# https://github.com/YisenWang/symmetric_cross_entropy_for_noisy_labels/blob/master/loss.py

# %%
def symmetric_cross_entropy(y_true, y_pred):
    alpha = 0.1
    beta = 1.0
    y_true_1 = y_true
    y_pred_1 = y_pred

    y_true_2 = y_true
    y_pred_2 = y_pred

    y_pred_1 = tf.clip_by_value(y_pred_1, 1e-7, 1.0)
    y_true_2 = tf.clip_by_value(y_true_2, 1e-4, 1.0)

    return alpha*tf.math.reduce_mean(-tf.math.reduce_sum(y_true_1 * tf.math.log(y_pred_1), axis = -1)) + beta*tf.math.reduce_mean(-tf.math.reduce_sum(y_pred_2 * tf.math.log(y_true_2), axis = -1))

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3), kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(5e-4)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    total_steps = int(trainX.shape[0]/64) * 100
    decay_steps = total_steps*0.8
    initial_learning_rate = 0.01
    warmup_steps = 1000
    target_learning_rate = 0.1
    alpha_2 = 0.001

    lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate, decay_steps ,alpha = alpha_2
    )
    # Optimization method
    opt = SGD(learning_rate=lr_warmup_decayed_fn, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss=symmetric_cross_entropy, metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset(noise_ratio=40, sym=True)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 47s 48ms/step - loss: 7.8943 - accuracy: 0.2638 - val_loss: 5.9028 - val_accuracy: 0.4714
# Epoch 2/100
# 782/782 [==============================] - 33s 42ms/step - loss: 7.2360 - accuracy: 0.3374 - val_loss: 5.4109 - val_accuracy: 0.5206
# Epoch 3/100
# 782/782 [==============================] - 35s 44ms/step - loss: 6.8582 - accuracy: 0.3784 - val_loss: 4.9586 - val_accuracy: 0.5692
# Epoch 4/100
# 782/782 [==============================] - 34s 44ms/step - loss: 6.6458 - accuracy: 0.4008 - val_loss: 4.3600 - val_accuracy: 0.6299
# Epoch 5/100
# 782/782 [==============================] - 35s 45ms/step - loss: 6.4651 - accuracy: 0.4188 - val_loss: 4.4561 - val_accuracy: 0.6190
# Epoch 6/100
# 782/782 [==============================] - 33s 42ms/step - loss: 6.3487 - accuracy: 0.4315 - val_loss: 3.6753 - val_accuracy: 0.6964
# Epoch 7/100
# 782/782 [==============================] - 34s 44ms/step - loss: 6.2363 - accuracy: 0.4437 - val_loss: 4.1865 - val_accuracy: 0.6452
# Epoch 8/100
# 782/782 [==============================] - 33s 42ms/step - loss: 6.2013 - accuracy: 0.4487 - val_loss: 3.6176 - val_accuracy: 0.7080
# Epoch 9/100
# 782/782 [==============================] - 34s 44ms/step - loss: 6.1072 - accuracy: 0.4578 - val_loss: 3.5830 - val_accuracy: 0.7087
# Epoch 10/100
# 782/782 [==============================] - 33s 43ms/step - loss: 6.0650 - accuracy: 0.4626 - val_loss: 3.7464 - val_accuracy: 0.6910
# Epoch 11/100
# 782/782 [==============================] - 34s 43ms/step - loss: 6.0119 - accuracy: 0.4684 - val_loss: 3.2481 - val_accuracy: 0.7483
# Epoch 12/100
# 782/782 [==============================] - 35s 44ms/step - loss: 6.0099 - accuracy: 0.4708 - val_loss: 3.4403 - val_accuracy: 0.7269
# Epoch 13/100
# 782/782 [==============================] - 34s 43ms/step - loss: 5
# Epoch 57/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.9609 - accuracy: 0.5708 - val_loss: 2.2301 - val_accuracy: 0.8456
# Epoch 58/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.9341 - accuracy: 0.5730 - val_loss: 2.1849 - val_accuracy: 0.8507
# Epoch 59/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.9090 - accuracy: 0.5745 - val_loss: 2.2209 - val_accuracy: 0.8460
# Epoch 60/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.8865 - accuracy: 0.5770 - val_loss: 2.2142 - val_accuracy: 0.8426
# Epoch 61/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.8454 - accuracy: 0.5805 - val_loss: 2.1257 - val_accuracy: 0.8543
# Epoch 62/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.8245 - accuracy: 0.5811 - val_loss: 2.1050 - val_accuracy: 0.8556
# Epoch 63/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.7796 - accuracy: 0.5857 - val_loss: 2.1104 - val_accuracy: 0.8540
# Epoch 64/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.7514 - accuracy: 0.5882 - val_loss: 2.1602 - val_accuracy: 0.8494
# Epoch 65/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.7398 - accuracy: 0.5886 - val_loss: 2.1162 - val_accuracy: 0.8514
# Epoch 66/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.7219 - accuracy: 0.5897 - val_loss: 2.1106 - val_accuracy: 0.8519
# Epoch 67/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.6898 - accuracy: 0.5932 - val_loss: 2.1032 - val_accuracy: 0.8519
# Epoch 68/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.6796 - accuracy: 0.5935 - val_loss: 2.0767 - val_accuracy: 0.8561
# Epoch 69/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.6469 - accuracy: 0.5960 - val_loss: 2.0990 - val_accuracy: 0.8525
# Epoch 70/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.6356 - accuracy: 0.5973 - val_loss: 2.0769 - val_accuracy: 0.8552
# Epoch 71/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.6103 - accuracy: 0.5989 - val_loss: 2.0879 - val_accuracy: 0.8558
# Epoch 72/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.6071 - accuracy: 0.5992 - val_loss: 2.0655 - val_accuracy: 0.8564
# Epoch 73/100
# 782/782 [==============================] - 33s 43ms/step - loss: 4.5953 - accuracy: 0.6003 - val_loss: 2.0685 - val_accuracy: 0.8559
# Epoch 74/100
# 782/782 [==============================] - 35s 45ms/step - loss: 4.5833 - accuracy: 0.6014 - val_loss: 2.0604 - val_accuracy: 0.8575
# Epoch 75/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5607 - accuracy: 0.6033 - val_loss: 2.0687 - val_accuracy: 0.8571
# Epoch 76/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.5655 - accuracy: 0.6023 - val_loss: 2.0548 - val_accuracy: 0.8583
# Epoch 77/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.5563 - accuracy: 0.6044 - val_loss: 2.0541 - val_accuracy: 0.8575
# Epoch 78/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5544 - accuracy: 0.6031 - val_loss: 2.0541 - val_accuracy: 0.8579
# Epoch 79/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.5695 - accuracy: 0.6019 - val_loss: 2.0530 - val_accuracy: 0.8579
# Epoch 80/100
# 782/782 [==============================] - 33s 43ms/step - loss: 4.5528 - accuracy: 0.6043 - val_loss: 2.0556 - val_accuracy: 0.8576
# Epoch 81/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.5560 - accuracy: 0.6035 - val_loss: 2.0492 - val_accuracy: 0.8594
# Epoch 82/100
# 782/782 [==============================] - 37s 47ms/step - loss: 4.5549 - accuracy: 0.6040 - val_loss: 2.0525 - val_accuracy: 0.8577
# Epoch 83/100
# 782/782 [==============================] - 35s 45ms/step - loss: 4.5338 - accuracy: 0.6062 - val_loss: 2.0516 - val_accuracy: 0.8583
# Epoch 84/100
# 782/782 [==============================] - 35s 44ms/step - loss: 4.5396 - accuracy: 0.6053 - val_loss: 2.0523 - val_accuracy: 0.8583
# Epoch 85/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.5547 - accuracy: 0.6036 - val_loss: 2.0486 - val_accuracy: 0.8590
# Epoch 86/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.5429 - accuracy: 0.6049 - val_loss: 2.0533 - val_accuracy: 0.8577
# Epoch 87/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5429 - accuracy: 0.6050 - val_loss: 2.0483 - val_accuracy: 0.8596
# Epoch 88/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.5414 - accuracy: 0.6058 - val_loss: 2.0494 - val_accuracy: 0.8598
# Epoch 89/100
# 782/782 [==============================] - 32s 41ms/step - loss: 4.5467 - accuracy: 0.6046 - val_loss: 2.0510 - val_accuracy: 0.8582
# Epoch 90/100
# 782/782 [==============================] - 35s 45ms/step - loss: 4.5459 - accuracy: 0.6046 - val_loss: 2.0483 - val_accuracy: 0.8585
# Epoch 91/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5509 - accuracy: 0.6045 - val_loss: 2.0497 - val_accuracy: 0.8590
# Epoch 92/100
# 782/782 [==============================] - 33s 43ms/step - loss: 4.5389 - accuracy: 0.6054 - val_loss: 2.0522 - val_accuracy: 0.8585
# Epoch 93/100
# 782/782 [==============================] - 32s 41ms/step - loss: 4.5589 - accuracy: 0.6029 - val_loss: 2.0487 - val_accuracy: 0.8585
# Epoch 94/100
# 782/782 [==============================] - 34s 43ms/step - loss: 4.5448 - accuracy: 0.6050 - val_loss: 2.0524 - val_accuracy: 0.8577
# Epoch 95/100
# 782/782 [==============================] - 32s 41ms/step - loss: 4.5390 - accuracy: 0.6051 - val_loss: 2.0480 - val_accuracy: 0.8590
# Epoch 96/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5407 - accuracy: 0.6054 - val_loss: 2.0471 - val_accuracy: 0.8576
# Epoch 97/100
# 782/782 [==============================] - 32s 41ms/step - loss: 4.5404 - accuracy: 0.6048 - val_loss: 2.0496 - val_accuracy: 0.8584
# Epoch 98/100
# 782/782 [==============================] - 33s 42ms/step - loss: 4.5551 - accuracy: 0.6034 - val_loss: 2.0481 - val_accuracy: 0.8576
# Epoch 99/100
# 782/782 [==============================] - 32s 41ms/step - loss: 4.5503 - accuracy: 0.6043 - val_loss: 2.0557 - val_accuracy: 0.8582
# Epoch 100/100
# 782/782 [==============================] - 34s 44ms/step - loss: 4.5397 - accuracy: 0.6047 - val_loss: 2.0548 - val_accuracy: 0.8573

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 85.73%

# %%
save_model('SL_40_noisy_model_sym_no_dropout', model)
save_history('SL_40_noisy_model_sym_no_dropout_hist', results.history)
