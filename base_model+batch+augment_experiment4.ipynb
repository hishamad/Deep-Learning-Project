# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):
	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)

	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)

	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/models/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/history/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/models/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/content/history/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Dense(10, activation='softmax'))

    # Optimization method
    opt = SGD(learning_rate=0.01, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 41s 44ms/step - loss: 1.3392 - accuracy: 0.5228 - val_loss: 1.1947 - val_accuracy: 0.5897
# Epoch 2/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9513 - accuracy: 0.6640 - val_loss: 0.9864 - val_accuracy: 0.6570
# Epoch 3/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.8008 - accuracy: 0.7198 - val_loss: 0.8587 - val_accuracy: 0.7026
# Epoch 4/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7153 - accuracy: 0.7506 - val_loss: 0.8467 - val_accuracy: 0.7141
# Epoch 5/100
# 782/782 [==============================] - 32s 42ms/step - loss: 0.6526 - accuracy: 0.7706 - val_loss: 0.6857 - val_accuracy: 0.7675
# Epoch 6/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.6029 - accuracy: 0.7897 - val_loss: 0.7736 - val_accuracy: 0.7333
# Epoch 7/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5616 - accuracy: 0.8058 - val_loss: 0.5702 - val_accuracy: 0.8046
# Epoch 8/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5347 - accuracy: 0.8135 - val_loss: 0.5908 - val_accuracy: 0.8004
# Epoch 9/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5020 - accuracy: 0.8251 - val_loss: 0.5926 - val_accuracy: 0.8025
# Epoch 10/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4764 - accuracy: 0.8353 - val_loss: 0.5875 - val_accuracy: 0.8041
# Epoch 11/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4559 - accuracy: 0.8410 - val_loss: 0.5378 - val_accuracy: 0.8158
# Epoch 12/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4381 - accuracy: 0.8469 - val_loss: 0.6293 - val_accuracy: 0.7932
# Epoch 13/100
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4154 - accuracy: 0.8547 - val_loss: 0.5232 - val_accuracy: 0.8262
# Epoch 14/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4020 - accuracy: 0.8605 - val_loss: 0.5248 - val_accuracy: 0.8297
# Epoch 15/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3851 - accuracy: 0.8655 - val_loss: 0.5552 - val_accuracy: 0.8181
# Epoch 16/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.3752 - accuracy: 0.8681 - val_loss: 0.6014 - val_accuracy: 0.8043
# Epoch 17/100
# 782/782 [==============================] - 33s 42ms/step - loss: 0.3605 - accuracy: 0.8718 - val_loss: 0.5620 - val_accuracy: 0.8202
# Epoch 18/100
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3490 - accuracy: 0.8776 - val_loss: 0.5142 - val_accuracy: 0.8340
# Epoch 19/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.3366 - accuracy: 0.8821 - val_loss: 0.4505 - val_accuracy: 0.8483
# Epoch 20/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3230 - accuracy: 0.8863 - val_loss: 0.4846 - val_accuracy: 0.8437
# Epoch 21/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.3167 - accuracy: 0.8887 - val_loss: 0.5038 - val_accuracy: 0.8359
# Epoch 22/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.3056 - accuracy: 0.8938 - val_loss: 0.4943 - val_accuracy: 0.8399
# Epoch 23/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2987 - accuracy: 0.8949 - val_loss: 0.4723 - val_accuracy: 0.8465
# Epoch 24/100
# 782/782 [==============================] - 39s 49ms/step - loss: 0.2843 - accuracy: 0.8991 - val_loss: 0.4450 - val_accuracy: 0.8529
# Epoch 25/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.2783 - accuracy: 0.9026 - val_loss: 0.4917 - val_accuracy: 0.8447
# Epoch 26/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2703 - accuracy: 0.9049 - val_loss: 0.4927 - val_accuracy: 0.8473
# Epoch 27/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.2639 - accuracy: 0.9073 - val_loss: 0.5005 - val_accuracy: 0.8473
# Epoch 28/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2626 - accuracy: 0.9074 - val_loss: 0.4842 - val_accuracy: 0.8491
# Epoch 29/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.2505 - accuracy: 0.9125 - val_loss: 0.4870 - val_accuracy: 0.8444
# Epoch 30/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2435 - accuracy: 0.9147 - val_loss: 0.4527 - val_accuracy: 0.8569
# Epoch 31/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2397 - accuracy: 0.9142 - val_loss: 0.4820 - val_accuracy: 0.8513
# Epoch 32/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.2297 - accuracy: 0.9179 - val_loss: 0.4926 - val_accuracy: 0.8499
# Epoch 33/100
# 782/782 [==============================] - 39s 50ms/step - loss: 0.2280 - accuracy: 0.9192 - val_loss: 0.4375 - val_accuracy: 0.8620
# Epoch 34/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.2221 - accuracy: 0.9205 - val_loss: 0.4633 - val_accuracy: 0.8587
# Epoch 35/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.2178 - accuracy: 0.9250 - val_loss: 0.4969 - val_accuracy: 0.8465
# Epoch 36/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.2124 - accuracy: 0.9243 - val_loss: 0.4656 - val_accuracy: 0.8579
# Epoch 37/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2068 - accuracy: 0.9269 - val_loss: 0.4561 - val_accuracy: 0.8602
# Epoch 38/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.2032 - accuracy: 0.9275 - val_loss: 0.4623 - val_accuracy: 0.8572
# Epoch 39/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1982 - accuracy: 0.9307 - val_loss: 0.4657 - val_accuracy: 0.8591
# Epoch 40/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.1958 - accuracy: 0.9298 - val_loss: 0.4607 - val_accuracy: 0.8616
# Epoch 41/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.1904 - accuracy: 0.9330 - val_loss: 0.4514 - val_accuracy: 0.8666
# Epoch 42/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1831 - accuracy: 0.9353 - val_loss: 0.4506 - val_accuracy: 0.8657
# Epoch 43/100
# 782/782 [==============================] - 38s 48ms/step - loss: 0.1783 - accuracy: 0.9367 - val_loss: 0.5617 - val_accuracy: 0.8422
# Epoch 44/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1824 - accuracy: 0.9352 - val_loss: 0.4791 - val_accuracy: 0.8637
# Epoch 45/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1750 - accuracy: 0.9365 - val_loss: 0.4653 - val_accuracy: 0.8676
# Epoch 46/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1709 - accuracy: 0.9388 - val_loss: 0.4648 - val_accuracy: 0.8657
# Epoch 47/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1700 - accuracy: 0.9389 - val_loss: 0.4639 - val_accuracy: 0.8643
# Epoch 48/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1649 - accuracy: 0.9420 - val_loss: 0.5261 - val_accuracy: 0.8472
# Epoch 49/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1639 - accuracy: 0.9413 - val_loss: 0.4974 - val_accuracy: 0.8613
# Epoch 50/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1629 - accuracy: 0.9423 - val_loss: 0.5236 - val_accuracy: 0.8545
# Epoch 51/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1567 - accuracy: 0.9432 - val_loss: 0.4716 - val_accuracy: 0.8674
# Epoch 52/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1524 - accuracy: 0.9447 - val_loss: 0.4777 - val_accuracy: 0.8661
# Epoch 53/100
# 782/782 [==============================] - 38s 48ms/step - loss: 0.1484 - accuracy: 0.9468 - val_loss: 0.4635 - val_accuracy: 0.8695
# Epoch 54/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1456 - accuracy: 0.9484 - val_loss: 0.4477 - val_accuracy: 0.8784
# Epoch 55/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1448 - accuracy: 0.9479 - val_loss: 0.4820 - val_accuracy: 0.8648
# Epoch 56/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.1450 - accuracy: 0.9477 - val_loss: 0.4681 - val_accuracy: 0.8705
# Epoch 57/100
# 782/782 [==============================] - 33s 43ms/step - loss: 0.1427 - accuracy: 0.9490 - val_loss: 0.4543 - val_accuracy: 0.8735
# Epoch 58/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.1370 - accuracy: 0.9506 - val_loss: 0.4889 - val_accuracy: 0.8676
# Epoch 59/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1368 - accuracy: 0.9511 - val_loss: 0.4687 - val_accuracy: 0.8714
# Epoch 60/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.1322 - accuracy: 0.9531 - val_loss: 0.4904 - val_accuracy: 0.8648
# Epoch 61/100
# 782/782 [==============================] - 38s 48ms/step - loss: 0.1337 - accuracy: 0.9517 - val_loss: 0.4868 - val_accuracy: 0.8662
# Epoch 62/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1344 - accuracy: 0.9518 - val_loss: 0.4586 - val_accuracy: 0.8725
# Epoch 63/100
# 782/782 [==============================] - 39s 49ms/step - loss: 0.1282 - accuracy: 0.9541 - val_loss: 0.4685 - val_accuracy: 0.8746
# Epoch 64/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.1285 - accuracy: 0.9542 - val_loss: 0.4789 - val_accuracy: 0.8707
# Epoch 65/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1262 - accuracy: 0.9556 - val_loss: 0.4803 - val_accuracy: 0.8709
# Epoch 66/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1232 - accuracy: 0.9560 - val_loss: 0.4944 - val_accuracy: 0.8636
# Epoch 67/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.1212 - accuracy: 0.9560 - val_loss: 0.4769 - val_accuracy: 0.8757
# Epoch 68/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1173 - accuracy: 0.9588 - val_loss: 0.4941 - val_accuracy: 0.8704
# Epoch 69/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1162 - accuracy: 0.9580 - val_loss: 0.4664 - val_accuracy: 0.8801
# Epoch 70/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.1184 - accuracy: 0.9569 - val_loss: 0.4834 - val_accuracy: 0.8705
# Epoch 71/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1143 - accuracy: 0.9601 - val_loss: 0.5172 - val_accuracy: 0.8693
# Epoch 72/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.1128 - accuracy: 0.9601 - val_loss: 0.5112 - val_accuracy: 0.8662
# Epoch 73/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1105 - accuracy: 0.9603 - val_loss: 0.5012 - val_accuracy: 0.8692
# Epoch 74/100
# 782/782 [==============================] - 39s 49ms/step - loss: 0.1115 - accuracy: 0.9602 - val_loss: 0.4783 - val_accuracy: 0.8720
# Epoch 75/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.1099 - accuracy: 0.9603 - val_loss: 0.4808 - val_accuracy: 0.8739
# Epoch 76/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1090 - accuracy: 0.9617 - val_loss: 0.4789 - val_accuracy: 0.8734
# Epoch 77/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1054 - accuracy: 0.9623 - val_loss: 0.4815 - val_accuracy: 0.8792
# Epoch 78/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1054 - accuracy: 0.9632 - val_loss: 0.4757 - val_accuracy: 0.8804
# Epoch 79/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.1009 - accuracy: 0.9645 - val_loss: 0.4670 - val_accuracy: 0.8800
# Epoch 80/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.1023 - accuracy: 0.9628 - val_loss: 0.4847 - val_accuracy: 0.8795
# Epoch 81/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.1023 - accuracy: 0.9642 - val_loss: 0.5044 - val_accuracy: 0.8751
# Epoch 82/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.0992 - accuracy: 0.9658 - val_loss: 0.4788 - val_accuracy: 0.8782
# Epoch 83/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.0964 - accuracy: 0.9655 - val_loss: 0.4805 - val_accuracy: 0.8780
# Epoch 84/100
# 782/782 [==============================] - 40s 51ms/step - loss: 0.0976 - accuracy: 0.9654 - val_loss: 0.4751 - val_accuracy: 0.8795
# Epoch 85/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.0964 - accuracy: 0.9661 - val_loss: 0.4870 - val_accuracy: 0.8785
# Epoch 86/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.0948 - accuracy: 0.9663 - val_loss: 0.5090 - val_accuracy: 0.8747
# Epoch 87/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.0942 - accuracy: 0.9661 - val_loss: 0.5029 - val_accuracy: 0.8758
# Epoch 88/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.0913 - accuracy: 0.9672 - val_loss: 0.5169 - val_accuracy: 0.8706
# Epoch 89/100
# 782/782 [==============================] - 38s 48ms/step - loss: 0.0941 - accuracy: 0.9661 - val_loss: 0.4902 - val_accuracy: 0.8791
# Epoch 90/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.0914 - accuracy: 0.9681 - val_loss: 0.4827 - val_accuracy: 0.8803
# Epoch 91/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.0907 - accuracy: 0.9671 - val_loss: 0.4834 - val_accuracy: 0.8810
# Epoch 92/100
# 782/782 [==============================] - 38s 49ms/step - loss: 0.0894 - accuracy: 0.9693 - val_loss: 0.5034 - val_accuracy: 0.8804
# Epoch 93/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.0908 - accuracy: 0.9669 - val_loss: 0.4970 - val_accuracy: 0.8787
# Epoch 94/100
# 782/782 [==============================] - 41s 52ms/step - loss: 0.0849 - accuracy: 0.9697 - val_loss: 0.5274 - val_accuracy: 0.8774
# Epoch 95/100
# 782/782 [==============================] - 40s 51ms/step - loss: 0.0831 - accuracy: 0.9705 - val_loss: 0.5216 - val_accuracy: 0.8727
# Epoch 96/100
# 782/782 [==============================] - 40s 51ms/step - loss: 0.0878 - accuracy: 0.9685 - val_loss: 0.4996 - val_accuracy: 0.8802
# Epoch 97/100
# 782/782 [==============================] - 39s 50ms/step - loss: 0.0852 - accuracy: 0.9697 - val_loss: 0.4948 - val_accuracy: 0.8782
# Epoch 98/100
# 782/782 [==============================] - 40s 51ms/step - loss: 0.0857 - accuracy: 0.9696 - val_loss: 0.5208 - val_accuracy: 0.8750
# Epoch 99/100
# 782/782 [==============================] - 39s 50ms/step - loss: 0.0839 - accuracy: 0.9702 - val_loss: 0.5118 - val_accuracy: 0.8765
# Epoch 100/100
# 782/782 [==============================] - 38s 48ms/step - loss: 0.0802 - accuracy: 0.9710 - val_loss: 0.5174 - val_accuracy: 0.8778

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 87.78%

# %%
save_model('batch_augment_model_experiment4', model)
save_history('batch_augment_model_experiment4', results.history)

# %%
from google.colab import files
files.download('/content/models/batch_augment_model_experiment4')
files.download('/content/history/batch_augment_model_experiment4')

# %%
test = load_model('batch_augment_model_experiment4')
history_test = load_history('batch_augment_model_experiment4')

# %%
plot_results(history_test)
evaluate(test, testX, testY)
# Out:
# The model achieved a final accuracy of 87.78%
