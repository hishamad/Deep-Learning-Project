# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from cosine_annealing import CosineAnnealingScheduler
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):

	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)

	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)

	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/models/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/history/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/models/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/content/history/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %%
int(trainX.shape[0]/64)*100
# Out:
# 78100

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    total_steps = int(trainX.shape[0]/64) * 100
    decay_steps = total_steps*0.8
    initial_learning_rate = 0.0001
    warmup_steps = 1000
    target_learning_rate = 0.1
    alpha = 0.001

    lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate, decay_steps, warmup_target=target_learning_rate,
        warmup_steps=warmup_steps,alpha = alpha
    )
    # Optimization method
    opt = SGD(learning_rate=lr_warmup_decayed_fn, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 39s 46ms/step - loss: 1.7704 - accuracy: 0.3876 - val_loss: 1.8888 - val_accuracy: 0.4116
# Epoch 2/100
# 782/782 [==============================] - 36s 46ms/step - loss: 1.2125 - accuracy: 0.5696 - val_loss: 1.7533 - val_accuracy: 0.4651
# Epoch 3/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.0124 - accuracy: 0.6479 - val_loss: 0.9287 - val_accuracy: 0.6814
# Epoch 4/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.9267 - accuracy: 0.6798 - val_loss: 0.7436 - val_accuracy: 0.7443
# Epoch 5/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.8477 - accuracy: 0.7092 - val_loss: 0.7567 - val_accuracy: 0.7503
# Epoch 6/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.8030 - accuracy: 0.7268 - val_loss: 0.8486 - val_accuracy: 0.7266
# Epoch 7/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.7629 - accuracy: 0.7403 - val_loss: 0.6804 - val_accuracy: 0.7724
# Epoch 8/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.7245 - accuracy: 0.7534 - val_loss: 0.6219 - val_accuracy: 0.7901
# Epoch 9/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.6968 - accuracy: 0.7622 - val_loss: 0.5873 - val_accuracy: 0.7988
# Epoch 10/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.6819 - accuracy: 0.7700 - val_loss: 0.6188 - val_accuracy: 0.7981
# Epoch 11/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.6553 - accuracy: 0.7772 - val_loss: 0.6492 - val_accuracy: 0.7813
# Epoch 12/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.6364 - accuracy: 0.7863 - val_loss: 0.5866 - val_accuracy: 0.8051
# Epoch 13/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.6183 - accuracy: 0.7917 - val_loss: 0.6750 - val_accuracy: 0.7870
# Epoch 14/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.6024 - accuracy: 0.7963 - val_loss: 0.5472 - val_accuracy: 0.8202
# Epoch 15/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.5913 - accuracy: 0.8021 - val_loss: 0.5149 - val_accuracy: 0.8340
# Epoch 16/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.5793 - accuracy: 0.8049 - val_loss: 0.6622 - val_accuracy: 0.7801
# Epoch 17/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.5670 - accuracy: 0.8094 - val_loss: 0.5149 - val_accuracy: 0.8321
# Epoch 18/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.5560 - accuracy: 0.8128 - val_loss: 0.5390 - val_accuracy: 0.8254
# Epoch 19/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.5461 - accuracy: 0.8186 - val_loss: 0.5210 - val_accuracy: 0.8290
# Epoch 20/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.5357 - accuracy: 0.8208 - val_loss: 0.4749 - val_accuracy: 0.8401
# Epoch 21/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.5263 - accuracy: 0.8233 - val_loss: 0.5344 - val_accuracy: 0.8284
# Epoch 22/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.5195 - accuracy: 0.8266 - val_loss: 0.4964 - val_accuracy: 0.8394
# Epoch 23/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.5156 - accuracy: 0.8275 - val_loss: 0.4543 - val_accuracy: 0.8492
# Epoch 24/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4972 - accuracy: 0.8334 - val_loss: 0.4563 - val_accuracy: 0.8504
# Epoch 25/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4947 - accuracy: 0.8338 - val_loss: 0.5089 - val_accuracy: 0.8359
# Epoch 26/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4870 - accuracy: 0.8360 - val_loss: 0.4155 - val_accuracy: 0.8644
# Epoch 27/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4833 - accuracy: 0.8369 - val_loss: 0.4714 - val_accuracy: 0.8487
# Epoch 28/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.4684 - accuracy: 0.8433 - val_loss: 0.4461 - val_accuracy: 0.8548
# Epoch 29/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4686 - accuracy: 0.8439 - val_loss: 0.4332 - val_accuracy: 0.8584
# Epoch 30/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.4549 - accuracy: 0.8477 - val_loss: 0.4232 - val_accuracy: 0.8605
# Epoch 31/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.4527 - accuracy: 0.8491 - val_loss: 0.4124 - val_accuracy: 0.8639
# Epoch 32/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.4471 - accuracy: 0.8504 - val_loss: 0.4611 - val_accuracy: 0.8524
# Epoch 33/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.4458 - accuracy: 0.8492 - val_loss: 0.4273 - val_accuracy: 0.8606
# Epoch 34/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4345 - accuracy: 0.8553 - val_loss: 0.5138 - val_accuracy: 0.8375
# Epoch 35/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.4339 - accuracy: 0.8541 - val_loss: 0.3914 - val_accuracy: 0.8717
# Epoch 36/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4187 - accuracy: 0.8599 - val_loss: 0.4447 - val_accuracy: 0.8571
# Epoch 37/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4214 - accuracy: 0.8570 - val_loss: 0.4258 - val_accuracy: 0.8634
# Epoch 38/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.4161 - accuracy: 0.8604 - val_loss: 0.3727 - val_accuracy: 0.8781
# Epoch 39/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4085 - accuracy: 0.8624 - val_loss: 0.4118 - val_accuracy: 0.8653
# Epoch 40/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4030 - accuracy: 0.8648 - val_loss: 0.4087 - val_accuracy: 0.8703
# Epoch 41/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3986 - accuracy: 0.8651 - val_loss: 0.4096 - val_accuracy: 0.8675
# Epoch 42/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3969 - accuracy: 0.8670 - val_loss: 0.4063 - val_accuracy: 0.8669
# Epoch 43/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3949 - accuracy: 0.8671 - val_loss: 0.3675 - val_accuracy: 0.8806
# Epoch 44/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.3877 - accuracy: 0.8692 - val_loss: 0.3725 - val_accuracy: 0.8810
# Epoch 45/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3806 - accuracy: 0.8709 - val_loss: 0.3899 - val_accuracy: 0.8745
# Epoch 46/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3763 - accuracy: 0.8731 - val_loss: 0.3757 - val_accuracy: 0.8823
# Epoch 47/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3713 - accuracy: 0.8735 - val_loss: 0.3543 - val_accuracy: 0.8846
# Epoch 48/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3627 - accuracy: 0.8789 - val_loss: 0.3620 - val_accuracy: 0.8837
# Epoch 49/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3705 - accuracy: 0.8744 - val_loss: 0.3803 - val_accuracy: 0.8789
# Epoch 50/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3632 - accuracy: 0.8767 - val_loss: 0.3683 - val_accuracy: 0.8813
# Epoch 51/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3562 - accuracy: 0.8794 - val_loss: 0.3784 - val_accuracy: 0.8809
# Epoch 52/100
# 782/782 [==============================] - 36s 47ms/step - loss: 0.3535 - accuracy: 0.8806 - val_loss: 0.3686 - val_accuracy: 0.8843
# Epoch 53/100
# 782/782 [==============================] - 37s 48ms/step - loss: 0.3560 - accuracy: 0.8796 - val_loss: 0.3544 - val_accuracy: 0.8864
# Epoch 54/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3433 - accuracy: 0.8845 - val_loss: 0.3795 - val_accuracy: 0.8792
# Epoch 55/100
# 782/782 [==============================] - 36s 47ms/step - loss: 0.3457 - accuracy: 0.8818 - val_loss: 0.3394 - val_accuracy: 0.8930
# Epoch 56/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3437 - accuracy: 0.8839 - val_loss: 0.3547 - val_accuracy: 0.8859
# Epoch 57/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3347 - accuracy: 0.8878 - val_loss: 0.3486 - val_accuracy: 0.8895
# Epoch 58/100
# 782/782 [==============================] - 36s 47ms/step - loss: 0.3329 - accuracy: 0.8863 - val_loss: 0.3578 - val_accuracy: 0.8847
# Epoch 59/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.3332 - accuracy: 0.8869 - val_loss: 0.3356 - val_accuracy: 0.8916
# Epoch 60/100
# 782/782 [==============================] - 36s 47ms/step - loss: 0.3310 - accuracy: 0.8886 - val_loss: 0.3405 - val_accuracy: 0.8951
# Epoch 61/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3316 - accuracy: 0.8880 - val_loss: 0.3330 - val_accuracy: 0.8950
# Epoch 62/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3202 - accuracy: 0.8928 - val_loss: 0.3372 - val_accuracy: 0.8916
# Epoch 63/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3259 - accuracy: 0.8884 - val_loss: 0.3314 - val_accuracy: 0.8930
# Epoch 64/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3258 - accuracy: 0.8885 - val_loss: 0.3416 - val_accuracy: 0.8904
# Epoch 65/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3197 - accuracy: 0.8907 - val_loss: 0.3435 - val_accuracy: 0.8927
# Epoch 66/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3197 - accuracy: 0.8903 - val_loss: 0.3385 - val_accuracy: 0.8939
# Epoch 67/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3190 - accuracy: 0.8924 - val_loss: 0.3330 - val_accuracy: 0.8951
# Epoch 68/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3153 - accuracy: 0.8935 - val_loss: 0.3318 - val_accuracy: 0.8969
# Epoch 69/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.3165 - accuracy: 0.8917 - val_loss: 0.3266 - val_accuracy: 0.8972
# Epoch 70/100
# 782/782 [==============================] - 34s 43ms/step - loss: 0.3158 - accuracy: 0.8937 - val_loss: 0.3324 - val_accuracy: 0.8944
# Epoch 71/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.3080 - accuracy: 0.8955 - val_loss: 0.3317 - val_accuracy: 0.8949
# Epoch 72/100
# 782/782 [==============================] - 36s 45ms/step - loss: 0.3088 - accuracy: 0.8944 - val_loss: 0.3356 - val_accuracy: 0.8942
# Epoch 73/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3068 - accuracy: 0.8958 - val_loss: 0.3322 - val_accuracy: 0.8953
# Epoch 74/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3066 - accuracy: 0.8959 - val_loss: 0.3338 - val_accuracy: 0.8955
# Epoch 75/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3051 - accuracy: 0.8956 - val_loss: 0.3321 - val_accuracy: 0.8942
# Epoch 76/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3089 - accuracy: 0.8958 - val_loss: 0.3333 - val_accuracy: 0.8943
# Epoch 77/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.3044 - accuracy: 0.8959 - val_loss: 0.3348 - val_accuracy: 0.8942
# Epoch 78/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3082 - accuracy: 0.8942 - val_loss: 0.3316 - val_accuracy: 0.8957
# Epoch 79/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3084 - accuracy: 0.8949 - val_loss: 0.3310 - val_accuracy: 0.8952
# Epoch 80/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3022 - accuracy: 0.8967 - val_loss: 0.3327 - val_accuracy: 0.8952
# Epoch 81/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.2969 - accuracy: 0.8977 - val_loss: 0.3333 - val_accuracy: 0.8951
# Epoch 82/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3031 - accuracy: 0.8970 - val_loss: 0.3331 - val_accuracy: 0.8946
# Epoch 83/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.3003 - accuracy: 0.8969 - val_loss: 0.3312 - val_accuracy: 0.8952
# Epoch 84/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3063 - accuracy: 0.8952 - val_loss: 0.3325 - val_accuracy: 0.8949
# Epoch 85/100
# 782/782 [==============================] - 37s 47ms/step - loss: 0.3034 - accuracy: 0.8980 - val_loss: 0.3317 - val_accuracy: 0.8954
# Epoch 86/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3023 - accuracy: 0.8969 - val_loss: 0.3326 - val_accuracy: 0.8953
# Epoch 87/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3019 - accuracy: 0.8959 - val_loss: 0.3333 - val_accuracy: 0.8946
# Epoch 88/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3023 - accuracy: 0.8979 - val_loss: 0.3328 - val_accuracy: 0.8946
# Epoch 89/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3030 - accuracy: 0.8969 - val_loss: 0.3322 - val_accuracy: 0.8949
# Epoch 90/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3039 - accuracy: 0.8949 - val_loss: 0.3337 - val_accuracy: 0.8944
# Epoch 91/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3058 - accuracy: 0.8968 - val_loss: 0.3328 - val_accuracy: 0.8948
# Epoch 92/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.3005 - accuracy: 0.8977 - val_loss: 0.3338 - val_accuracy: 0.8945
# Epoch 93/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3028 - accuracy: 0.8966 - val_loss: 0.3327 - val_accuracy: 0.8941
# Epoch 94/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3040 - accuracy: 0.8954 - val_loss: 0.3327 - val_accuracy: 0.8949
# Epoch 95/100
# 782/782 [==============================] - 34s 44ms/step - loss: 0.2997 - accuracy: 0.8977 - val_loss: 0.3339 - val_accuracy: 0.8940
# Epoch 96/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3059 - accuracy: 0.8959 - val_loss: 0.3330 - val_accuracy: 0.8948
# Epoch 97/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3037 - accuracy: 0.8970 - val_loss: 0.3337 - val_accuracy: 0.8943
# Epoch 98/100
# 782/782 [==============================] - 35s 44ms/step - loss: 0.3024 - accuracy: 0.8973 - val_loss: 0.3315 - val_accuracy: 0.8955
# Epoch 99/100
# 782/782 [==============================] - 35s 45ms/step - loss: 0.3001 - accuracy: 0.8988 - val_loss: 0.3309 - val_accuracy: 0.8949
# Epoch 100/100
# 782/782 [==============================] - 36s 46ms/step - loss: 0.2999 - accuracy: 0.8985 - val_loss: 0.3327 - val_accuracy: 0.8938

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 89.38%

# %%
save_model('cosine_model', model)
save_history('cosine_hist', results.history)

# %%
from google.colab import files
files.download('/content/models/cosine_model')
files.download('/content/history/cosine_hist')

# %%
test = load_model('cosine_model')
history_test = load_history('cosine_hist')

# %%
plot_results(history_test)
evaluate(test, testX, testY)
# Out:
# The model achieved a final accuracy of 89.38%
