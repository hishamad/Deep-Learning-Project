# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from cosine_annealing import CosineAnnealingScheduler
from keras.layers import BatchNormalization
import pickle
from keras.regularizers import l2
from  scipy import ndimage
import numpy as np

# %% [markdown]
# #### Dataset

# %% [markdown]
# Load dataset + One-hot encoding + Normalization

# %%
def load_dataset(noise_ratio=0, sym=True):
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    n_classes = 10

    if noise_ratio > 0:
        trainY_original = np.copy(trainY)
        if not sym:
            # Asymetric noise
            source_class = [9, 2, 3, 5, 4]
            target_class = [1, 0, 5, 3, 7]

            for s, t in zip(source_class, target_class):
                cls_idx = np.where(trainY_original == s)[0]
                n_noisy = int(noise_ratio * cls_idx.shape[0] / 100)
                noisy_sample_index = np.random.choice(cls_idx, n_noisy, replace=False)
                trainY[noisy_sample_index] = t
        else:
          # Symmetric noise

            n_samples = trainY.shape[0]
            n_noisy = int(noise_ratio * n_samples / 100)
            class_index = [np.where(trainY_original == i)[0] for i in range(n_classes)]
            class_noisy = int(n_noisy / n_classes)

            noisy_idx = []
            for d in range(n_classes):
                noisy_class_index = np.random.choice(class_index[d], class_noisy, replace=False)
                noisy_idx.extend(noisy_class_index)

            for i in noisy_idx:
                class_ind = trainY_original[i]
                other_class_list = list(range(n_classes))
                other_class_list.remove(class_ind)
                other_class = np.random.choice(other_class_list)
                trainY[i] = other_class

    # One-hot encoding
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    # Normalize to [0,1]
    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    return trainX, trainY, testX, testY

# %% [markdown]
# #### Model

# %% [markdown]
# Imortant functions

# %%
def train(model, trainX, trainY, testX, testY):

	generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

	train_data = generator.flow(trainX, trainY, batch_size=64)

	results = model.fit(train_data, epochs=100, validation_data=(testX, testY), verbose=1)

	return results

def evaluate(model, testX, testY):
    _, acc = model.evaluate(testX, testY, verbose=0)

    print(f"The model achieved a final accuracy of {acc*100:.2f}%")

def plot_results(history):
	plt.title('Cross Entropy Loss')
	plt.plot(history['loss'], color='blue', label='Training loss')
	plt.plot(history['val_loss'], color='orange', label='Validation/test loss')
	plt.legend()
	plt.show()

	plt.title('Classification Accuracy')
	plt.plot(history['accuracy'], color='blue', label='Training accuracy')
	plt.plot(history['val_accuracy'], color='orange', label='Validation/test accuracy')
	plt.legend()
	plt.show()

# %%
def save_model(filename, model):
    filename = '/content/' + filename
    pickle.dump(model, open(filename, 'wb'))

def save_history(filename, history):
    filename = '/content/' + filename
    pickle.dump(history, open(filename, 'wb'))

def load_model(filename):
    filename = '/content/' + filename
    model = pickle.load(open(filename, 'rb'))
    return model

def load_history(filename):
    filename = '/content/' + filename
    history = pickle.load(open(filename, 'rb'))
    return history

# %% [markdown]
# Baseline model

# %%
def dropout_model():
    # Create architecture
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    #model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    #model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    total_steps = int(trainX.shape[0]/64) * 100
    decay_steps = total_steps*0.8
    initial_learning_rate = 0.0001
    warmup_steps = 1000
    target_learning_rate = 0.1
    alpha = 0.001

    lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate, decay_steps, warmup_target=target_learning_rate,
        warmup_steps=warmup_steps,alpha = alpha
    )
    # Optimization method
    opt = SGD(learning_rate=lr_warmup_decayed_fn, momentum=0.9)

    # Compile model and choose loss type
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
trainX, trainY, testX, testY = load_dataset(noise_ratio=40, sym=True)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
model = dropout_model()
results = train(model, trainX, trainY, testX, testY)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 40s 43ms/step - loss: 2.2370 - accuracy: 0.2415 - val_loss: 2.7235 - val_accuracy: 0.1298
# Epoch 2/100
# 782/782 [==============================] - 35s 44ms/step - loss: 2.0189 - accuracy: 0.3379 - val_loss: 1.4920 - val_accuracy: 0.5436
# Epoch 3/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.9500 - accuracy: 0.3824 - val_loss: 1.6204 - val_accuracy: 0.4498
# Epoch 4/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.9129 - accuracy: 0.4079 - val_loss: 1.4244 - val_accuracy: 0.5792
# Epoch 5/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.8824 - accuracy: 0.4275 - val_loss: 1.2420 - val_accuracy: 0.6950
# Epoch 6/100
# 782/782 [==============================] - 33s 43ms/step - loss: 1.8644 - accuracy: 0.4373 - val_loss: 1.3838 - val_accuracy: 0.6236
# Epoch 7/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.8492 - accuracy: 0.4449 - val_loss: 1.1954 - val_accuracy: 0.6806
# Epoch 8/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.8311 - accuracy: 0.4566 - val_loss: 1.1538 - val_accuracy: 0.7050
# Epoch 9/100
# 782/782 [==============================] - 33s 43ms/step - loss: 1.8185 - accuracy: 0.4611 - val_loss: 1.1383 - val_accuracy: 0.7442
# Epoch 10/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.8033 - accuracy: 0.4668 - val_loss: 1.1303 - val_accuracy: 0.7427
# Epoch 11/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.7931 - accuracy: 0.4728 - val_loss: 1.1637 - val_accuracy: 0.7092
# Epoch 12/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.7828 - accuracy: 0.4750 - val_loss: 1.0958 - val_accuracy: 0.7538
# Epoch 13/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.7742 - accuracy: 0.4802 - val_loss: 1.0724 - val_accuracy: 0.7425
# Epoch 14/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.7616 - accuracy: 0.4835 - val_loss: 1.0886 - val_accuracy: 0.7370
# Epoch 15/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.7567 - accuracy: 0.4866 - val_loss: 1.1434 - val_accuracy: 0.7109
# Epoch 16/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.7407 - accuracy: 0.4936 - val_loss: 1.0500 - val_accuracy: 0.7744
# Epoch 17/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.7385 - accuracy: 0.4918 - val_loss: 1.1304 - val_accuracy: 0.7672
# Epoch 18/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.7273 - accuracy: 0.4971 - val_loss: 1.1618 - val_accuracy: 0.7422
# Epoch 19/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.7211 - accuracy: 0.4971 - val_loss: 1.1477 - val_accuracy: 0.7112
# Epoch 20/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.7110 - accuracy: 0.5004 - val_loss: 1.1096 - val_accuracy: 0.7437
# Epoch 21/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.7041 - accuracy: 0.5033 - val_loss: 1.0433 - val_accuracy: 0.7577
# Epoch 22/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6944 - accuracy: 0.5052 - val_loss: 0.9998 - val_accuracy: 0.7856
# Epoch 23/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.6825 - accuracy: 0.5106 - val_loss: 0.9849 - val_accuracy: 0.7654
# Epoch 24/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6804 - accuracy: 0.5087 - val_loss: 1.1187 - val_accuracy: 0.7430
# Epoch 25/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.6688 - accuracy: 0.5127 - val_loss: 1.0494 - val_accuracy: 0.7617
# Epoch 26/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6588 - accuracy: 0.5164 - val_loss: 1.0091 - val_accuracy: 0.7726
# Epoch 27/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.6531 - accuracy: 0.5166 - val_loss: 1.0846 - val_accuracy: 0.7440
# Epoch 28/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6452 - accuracy: 0.5187 - val_loss: 0.9736 - val_accuracy: 0.7711
# Epoch 29/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.6383 - accuracy: 0.5188 - val_loss: 1.0339 - val_accuracy: 0.7592
# Epoch 30/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.6296 - accuracy: 0.5203 - val_loss: 0.9807 - val_accuracy: 0.7665
# Epoch 31/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.6229 - accuracy: 0.5210 - val_loss: 1.1257 - val_accuracy: 0.7398
# Epoch 32/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6113 - accuracy: 0.5246 - val_loss: 0.9551 - val_accuracy: 0.7773
# Epoch 33/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.6006 - accuracy: 0.5269 - val_loss: 0.9921 - val_accuracy: 0.7697
# Epoch 34/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.5866 - accuracy: 0.5303 - val_loss: 1.0107 - val_accuracy: 0.7648
# Epoch 35/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.5804 - accuracy: 0.5335 - val_loss: 0.9967 - val_accuracy: 0.7599
# Epoch 36/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.5746 - accuracy: 0.5313 - val_loss: 0.9589 - val_accuracy: 0.7633
# Epoch 37/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.5658 - accuracy: 0.5341 - val_loss: 1.0266 - val_accuracy: 0.7576
# Epoch 38/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.5515 - accuracy: 0.5374 - val_loss: 0.9682 - val_accuracy: 0.7572
# Epoch 39/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.5414 - accuracy: 0.5400 - val_loss: 0.9961 - val_accuracy: 0.7565
# Epoch 40/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.5319 - accuracy: 0.5406 - val_loss: 0.9614 - val_accuracy: 0.7684
# Epoch 41/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.5236 - accuracy: 0.5417 - val_loss: 0.9981 - val_accuracy: 0.7511
# Epoch 42/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.5152 - accuracy: 0.5420 - val_loss: 0.9545 - val_accuracy: 0.7619
# Epoch 43/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.4987 - accuracy: 0.5481 - val_loss: 1.0830 - val_accuracy: 0.7202
# Epoch 44/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.4920 - accuracy: 0.5476 - val_loss: 0.9997 - val_accuracy: 0.7452
# Epoch 45/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.4809 - accuracy: 0.5482 - val_loss: 1.0028 - val_accuracy: 0.7505
# Epoch 46/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.4681 - accuracy: 0.5519 - val_loss: 0.9825 - val_accuracy: 0.7483
# Epoch 47/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4589 - accuracy: 0.5557 - val_loss: 1.1116 - val_accuracy: 0.7075
# Epoch 48/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.4424 - accuracy: 0.5599 - val_loss: 0.9878 - val_accuracy: 0.7365
# Epoch 49/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.4349 - accuracy: 0.5605 - val_loss: 1.0283 - val_accuracy: 0.7366
# Epoch 50/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.4258 - accuracy: 0.5638 - val_loss: 1.0338 - val_accuracy: 0.7301
# Epoch 51/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.4170 - accuracy: 0.5646 - val_loss: 1.0492 - val_accuracy: 0.7317
# Epoch 52/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.4024 - accuracy: 0.5668 - val_loss: 0.9956 - val_accuracy: 0.7363
# Epoch 53/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.3881 - accuracy: 0.5681 - val_loss: 1.0826 - val_accuracy: 0.7141
# Epoch 54/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3790 - accuracy: 0.5743 - val_loss: 1.0067 - val_accuracy: 0.7319
# Epoch 55/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.3696 - accuracy: 0.5764 - val_loss: 1.0373 - val_accuracy: 0.7279
# Epoch 56/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3584 - accuracy: 0.5771 - val_loss: 1.0271 - val_accuracy: 0.7278
# Epoch 57/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.3440 - accuracy: 0.5815 - val_loss: 1.0109 - val_accuracy: 0.7323
# Epoch 58/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.3320 - accuracy: 0.5852 - val_loss: 1.0625 - val_accuracy: 0.7172
# Epoch 59/100
# 782/782 [==============================] - 32s 42ms/step - loss: 1.3203 - accuracy: 0.5861 - val_loss: 1.0585 - val_accuracy: 0.7111
# Epoch 60/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.3099 - accuracy: 0.5888 - val_loss: 1.0714 - val_accuracy: 0.7065
# Epoch 61/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3013 - accuracy: 0.5920 - val_loss: 1.0322 - val_accuracy: 0.7195
# Epoch 62/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.2880 - accuracy: 0.5933 - val_loss: 1.0547 - val_accuracy: 0.7125
# Epoch 63/100
# 782/782 [==============================] - 32s 42ms/step - loss: 1.2768 - accuracy: 0.5969 - val_loss: 1.0394 - val_accuracy: 0.7078
# Epoch 64/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.2715 - accuracy: 0.5997 - val_loss: 1.0466 - val_accuracy: 0.7132
# Epoch 65/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.2574 - accuracy: 0.6025 - val_loss: 1.0464 - val_accuracy: 0.7084
# Epoch 66/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.2447 - accuracy: 0.6057 - val_loss: 1.0504 - val_accuracy: 0.7069
# Epoch 67/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.2348 - accuracy: 0.6100 - val_loss: 1.0609 - val_accuracy: 0.7023
# Epoch 68/100
# 782/782 [==============================] - 32s 41ms/step - loss: 1.2313 - accuracy: 0.6100 - val_loss: 1.0823 - val_accuracy: 0.6978
# Epoch 69/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.2183 - accuracy: 0.6127 - val_loss: 1.0872 - val_accuracy: 0.6932
# Epoch 70/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.2150 - accuracy: 0.6139 - val_loss: 1.0612 - val_accuracy: 0.6971
# Epoch 71/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.2132 - accuracy: 0.6140 - val_loss: 1.0734 - val_accuracy: 0.6931
# Epoch 72/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.1993 - accuracy: 0.6169 - val_loss: 1.0926 - val_accuracy: 0.6895
# Epoch 73/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1971 - accuracy: 0.6180 - val_loss: 1.0797 - val_accuracy: 0.6920
# Epoch 74/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1906 - accuracy: 0.6206 - val_loss: 1.0888 - val_accuracy: 0.6855
# Epoch 75/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1910 - accuracy: 0.6211 - val_loss: 1.0864 - val_accuracy: 0.6879
# Epoch 76/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1863 - accuracy: 0.6209 - val_loss: 1.0856 - val_accuracy: 0.6866
# Epoch 77/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1750 - accuracy: 0.6238 - val_loss: 1.0894 - val_accuracy: 0.6857
# Epoch 78/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1825 - accuracy: 0.6230 - val_loss: 1.0926 - val_accuracy: 0.6850
# Epoch 79/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.1739 - accuracy: 0.6269 - val_loss: 1.0925 - val_accuracy: 0.6853
# Epoch 80/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1707 - accuracy: 0.6254 - val_loss: 1.0928 - val_accuracy: 0.6863
# Epoch 81/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.1687 - accuracy: 0.6255 - val_loss: 1.0934 - val_accuracy: 0.6857
# Epoch 82/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1698 - accuracy: 0.6258 - val_loss: 1.0879 - val_accuracy: 0.6878
# Epoch 83/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1708 - accuracy: 0.6238 - val_loss: 1.0927 - val_accuracy: 0.6861
# Epoch 84/100
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1744 - accuracy: 0.6258 - val_loss: 1.0874 - val_accuracy: 0.6883
# Epoch 85/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1629 - accuracy: 0.6284 - val_loss: 1.0914 - val_accuracy: 0.6863
# Epoch 86/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1679 - accuracy: 0.6262 - val_loss: 1.0919 - val_accuracy: 0.6855
# Epoch 87/100
# 782/782 [==============================] - 33s 43ms/step - loss: 1.1785 - accuracy: 0.6236 - val_loss: 1.0903 - val_accuracy: 0.6846
# Epoch 88/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1770 - accuracy: 0.6205 - val_loss: 1.0926 - val_accuracy: 0.6858
# Epoch 89/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1696 - accuracy: 0.6255 - val_loss: 1.0920 - val_accuracy: 0.6871
# Epoch 90/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1736 - accuracy: 0.6264 - val_loss: 1.0941 - val_accuracy: 0.6854
# Epoch 91/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1751 - accuracy: 0.6261 - val_loss: 1.0961 - val_accuracy: 0.6840
# Epoch 92/100
# 782/782 [==============================] - 33s 43ms/step - loss: 1.1741 - accuracy: 0.6238 - val_loss: 1.0917 - val_accuracy: 0.6861
# Epoch 93/100
# 782/782 [==============================] - 35s 44ms/step - loss: 1.1755 - accuracy: 0.6229 - val_loss: 1.0942 - val_accuracy: 0.6847
# Epoch 94/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1714 - accuracy: 0.6246 - val_loss: 1.0905 - val_accuracy: 0.6866
# Epoch 95/100
# 782/782 [==============================] - 35s 45ms/step - loss: 1.1766 - accuracy: 0.6235 - val_loss: 1.0914 - val_accuracy: 0.6861
# Epoch 96/100
# 782/782 [==============================] - 33s 43ms/step - loss: 1.1687 - accuracy: 0.6254 - val_loss: 1.0919 - val_accuracy: 0.6860
# Epoch 97/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1640 - accuracy: 0.6270 - val_loss: 1.0910 - val_accuracy: 0.6872
# Epoch 98/100
# 782/782 [==============================] - 41s 53ms/step - loss: 1.1818 - accuracy: 0.6218 - val_loss: 1.0935 - val_accuracy: 0.6855
# Epoch 99/100
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1732 - accuracy: 0.6245 - val_loss: 1.0946 - val_accuracy: 0.6854
# Epoch 100/100
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1669 - accuracy: 0.6271 - val_loss: 1.0924 - val_accuracy: 0.6849

# %%
plot_results(results.history)
evaluate(model, testX, testY)
# Out:
# The model achieved a final accuracy of 68.49%

# %%
save_model('CE_noisy_model_40_sym_no_dropout', model)
save_history('CE_noisy_model_40_sym_no_dropout_hist', results.history)
